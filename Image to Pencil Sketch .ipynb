# %% [markdown]
# ![download.png](attachment:download.png)

# %% [markdown]
# ## LetsGrowMore VIP Data Science
#
# ## Task 3 - Image to Pencil Sketch
#
# ## Code Author - Manoj Kumar
#
# ### Importing Modules

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load and Plot original Image

# %%
img = cv2.imread("D:\Datasets\LGM Data files\Project 3\image.png")
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(8,8))
plt.imshow(img)
plt.axis("off")
plt.title("Original Image")
plt.show()

# %% [markdown]
# ### Converting Image to GrayScale

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(8,8))
plt.imshow(img_gray,cmap="gray")
plt.axis("off")
plt.title("GrayScale Image")
plt.show()

# %% [markdown]
# ### Inverting the Image

# %%
img_invert = cv2.bitwise_not(img_gray)
plt.figure(figsize=(8,8))
plt.imshow(img_invert,cmap="gray")
plt.axis("off")
plt.title("Inverted Image")
plt.show()

# %% [markdown]
# ### Smoothening the image

# %%
img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)
plt.figure(figsize=(8,8))
plt.imshow(img_smoothing,cmap="gray")
plt.axis("off")
plt.title("Smoothen Image")
plt.show()

# %% [markdown]
# ### Converting your images to pencil sketches

# %%
final = cv2.divide(img_gray, 255 - img_smoothing, scale=255)
plt.figure(figsize=(8,8))
plt.imshow(final,cmap="gray")
plt.axis("off")
plt.title("Final Sketch Image")
plt.show()

# %% [markdown]
# ### Display Original and Sketch Image

# %%
plt.figure(figsize=(20,20))
plt.subplot(1,2,1)
plt.imshow(img)
plt.axis("off")
plt.title("Original Image")
plt.subplot(1,2,2)
plt.imshow(final,cmap="gray")
plt.axis("off")
plt.title("Final Sketch Image")
plt.show()

# %% [markdown]
# ### Summary
#
# ### This project is used to convert the Original image format file into pencil sketch image. We can covert this using pythn open-cv function.
#
# ### *Happy coding and learnig !!*
